# %%
# Строки, начинающиеся с символа # — это *комментарии*

"""
Комментарии - это примечания, которые автор программы пишет
для других разработчиков. 

Python игнорирует любые символы на строчке после #, и заодно выделяет
комментарии цветом, что упрощает чтение кода

Если символом комментария скрыть часть кода — Python перестанет
видеть этот код и не станет его выполнять.

Закомментируем код ниже сочетанием клавиш Ctrl+/. При запуске ячейки
код не выполнится.
"""
# print('Роботы скоро спасут мир!')

# print('Я твоя программа, мне тут нравится! 👾')

# %%
"""
Не следует путать комментарии и так называемые докстринги. В коде
докстринги оборачиваются тремя двойными кавычками. Например, сейчас
мы пишем именно докстринг. 

В реальных проектах докстринги строго стандартизируются и предназначены
для документирования кода. Это более серьёзный инструмент, нежели 
обычные комментарии. К докстрингам можно обращаться программно, и они
лежат в основе механизма автоматического создания документации (например,
в фреймворке FastAPI). 
"""

# %%
"""
Комментарии в реальных проектах встречаются редко. Частое использование
комментариев уместно лишь на этапе обучения. Их используют, чтобы пояснить
работу новых, ранее не изученных строк кода.

Пояснение каждой строки в реальном проекте только помешает его чтению.
Однако, здесь есть важное уточнение: сам код должен писаться таким образом,
чтобы другой разработчик понимал его без всяких комментариев. Для этого 
существует ряд соглашений и стандартов.

Самый первый и важный стандарт офрмления кода - PEP8. Этот стандарт
определяет внешний вид кода: порядок импортов, порядок определения констант,
порядок отступов, длину строки кода и многое другое. 

Другое очень важное требование - это правильный нейминг. Имена переменных,
констант, функций, классов и, наконец, самих файлов проекта - всё это 
подчиняется определённым соглашениям. Правильный нейминг подразумевает то,
что сущности должны быть именованны осмысленно, согласно их содержанию.

Следование стандартам и соглашениям налагает на разработчика дополнительные
обязанности. Но в конечном итоге, все только выигрывают за счёт того, что
в будущем коллеги и сам разработчик смогут достаточно уверенно этот код
прочитать. На самом деле, 90% времени тратиться не на написание кода, а на
его чтение.

Тем не менее, существует ряд случаев, когда комментарии в реальных проектах
уместны. 1. Специальные комментарии для линтеров, например, для внесения 
некоторых строк или целых файлов в исключение. 2. Комментарии в тех местах,
где по той или иной причине, мы вынуждены делать временные решения, или 
делать что-то странное.  

"""
# Out:
# '\nКомментарии в реальных проектах встречаются редко. Частое использование\nкомментариев уместно лишь на этапе обучения. Их используют, чтобы пояснить\nработу новых, ранее не изученных строк кода.\n\nПояснение каждой строки в реальном проекте только помешает его чтению.\n'
