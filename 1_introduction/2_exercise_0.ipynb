# %%
"""
name = 'Вася'
print('Здесь был', name)

Вопрос: что делает эта программа?

Первая команда: "положить в переменную name слово 'Вася'".
Вторая команда: "напечатать на экран сообщение 'Здесь был' и
то слово, которое хранится в переменной name"

Ответ: программа печатает на экран сообщение "Здесь был Вася"
Запустим программу:
"""
name = 'Вася'
print('Здесь был', name)
# Out:
# Здесь был, Вася
